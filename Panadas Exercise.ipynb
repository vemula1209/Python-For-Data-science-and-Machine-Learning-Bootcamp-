# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']

# %%
my_data = [10,20,30]

# %%
arr = np.array(my_data)

# %%
d = {'a':10,'b':20,'c':30}

# %%
labels
# Out:
# ['a', 'b', 'c']

# %%
my_data

# %%
arr

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(my_data,index=labels)

# %%
pd.Series(arr)

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A -0.096100  0.391940 -0.439128 -1.217551
# B -0.800188 -0.329103  0.618500  0.489439
# C -0.708518  1.605276  1.631509  1.441777
# D -0.165641  0.643267 -0.649433 -0.412828
# E  1.302784 -1.589680  1.046731  0.400829

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df['New'] = df['W']+df['X']

# %%
df
# Out:
#           W         X         Y         Z       New
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.drop(labels='New',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['W']>0) & (df['X']<0)]
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
(df[df['W'>0]&df[df['X']<0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b96d99813e1e> in <module>()
# ----> 1 (df[df['W'>0]&df[df['X']<0]])
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['new'] = df['W']+df['X']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6983677cc901> in <module>()
# ----> 1 df.reset_index()
#
# NameError: name 'df' is not defined

# %%
df.set_index('new',inplace=True)

# %%
df
# Out:
#                   W         X         Y         Z
# new
#  3.334983  2.706850  0.628133  0.907969  0.503826
#  0.331800  0.651118 -0.319318 -0.848077  0.605965
# -1.278046 -2.018168  0.740122  0.528813 -0.589001
# -0.570177  0.188695 -0.758872 -0.933237  0.955057
#  2.169552  0.190794  1.978757  2.605967  0.683509

# %%
df.set_index('Z',inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0.503825753822, 0.605965349495, -0.589000533287, 0.955056509264, 0.683508885539]

# %%
df.reset_index()
# Out:
#           Z
# 0  0.503826
# 1  0.605965
# 2 -0.589001
# 3  0.955057
# 4  0.683509

# %%
sal = pd.read_csv('Salaries.CSV')

# %%
sal[sal['COUNTRY'] == 'India']
# Out:
#    COUNTRY  GDP (BILLIONS) CODE
# 92   India          2048.0  IND

# %%
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
salary
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
mean
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
# 5         118602.00
# 6          92492.01
# 7         256576.96
# 8         176932.64
# 9         285262.00
# 10        194999.39
# 11         99722.00
# 12        294580.02
# 13        271329.03
# 14        174872.64
# 15        198778.01
# 16        268604.57
# 17        140546.87
# 18        168692.63
# 19        257510.59
# 20        257510.48
# 21        257510.44
# 22        140546.88
# 23        168692.63
# 24        140546.86
# 25        256470.41
# 26         92080.80
# 27        168692.59
# 28        261717.60
# 29        246225.60
#             ...
# 148624         0.00
# 148625         0.00
# 148626         0.00
# 148627         0.00
# 148628         0.00
# 148629         0.00
# 148630         0.00
# 148631         0.00
# 148632         0.00
# 148633         0.00
# 148634         0.00
# 148635         0.00
# 148636         0.00
# 148637         0.00
# ...

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal.('Year').m

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
sal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-54cccfe2e1b3> in <module>()
# ----> 1 sal
#
# NameError: name 'sal' is not defined

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
sal[sal['EmployeeName'] =='JOSEPH DRISCOLL' ]['TotalPay']
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %%
sal['TotalPay'].max()

# %%
sal[sal['TotalPay']== sal['TotalPay'].max()]#['EmployeeName']
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal[sal['TotalPay'] == sal['TotalPay'].min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
sal.groupby( 'Year').mean()[['BasePay']]
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
# How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)

# %%
sal.groupby('EmployeeName')['JobTitle']

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
sal[sal['Year']==2013].count()
# Out:
# Id                  37606
# EmployeeName        37606
# JobTitle            37606
# BasePay             37001
# OvertimePay         37606
# OtherPay            37606
# Benefits            37606
# TotalPay            37606
# TotalPayBenefits    37606
# Year                37606
# Notes                   0
# Agency              37606
# Status                  0
# dtype: int64

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
# How many people have the word Chief in their job title? (This is pretty tricky)

# %%
def chief_start(titel):
    if 'chief' in titel.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_start(x)))
# Out:
# 627

# %%
def cheif_start(title):
    if 'cheif' in title.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_start(x)))
# Out:
# 627

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %%
#Bonus: Is there a correlation between length of the Job Title string and Salary?

# %%
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

# %%
sal['title_len']
# Out:
# 0         46
# 1         31
# 2         31
# 3         36
# 4         44
# 5         25
# 6         34
# 7         30
# 8         34
# 9         38
# 10        48
# 11        31
# 12        27
# 13        17
# 14        34
# 15        34
# 16        17
# 17        37
# 18        34
# 19        26
# 20        26
# 21        26
# 22        25
# 23        34
# 24        25
# 25        15
# 26        25
# 27        34
# 28        36
# 29        44
#           ..
# 148624    12
# 148625    16
# 148626    13
# 148627    15
# 148628    15
# 148629    18
# 148630     9
# 148631    27
# 148632    26
# 148633    15
# 148634    19
# 148635    15
# 148636    19
# 148637    22
# 148638    11
# 148639     9
# 148640    23
# 148641    12
# 148642    11
# 148643    23
# 148644    28
# 148645    25
# 148646    12
# 148647    27
# 148648     9
# 148649     9
# 148650    12
# 148651    12
# 148652    12
# 148653    26
# Name: title_len, Length: 148654, dtype: int64

# %%
sal[['title_len','TotalPayBenefits']].corr()
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

# %%
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
sal['TotalPay'].head(5)
# Out:
# 0    567595.43
# 1    538909.28
# 2    335279.91
# 3    332343.61
# 4    326373.19
# Name: TotalPay, dtype: float64

# %%
Ecom_Data = pd.read_csv('Ecommerce Purchases.csv')

# %%
Ecom_Data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
Ecom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
Ecom_Data['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
Ecom_Data['Purchase Price'].max()
# Out:
# 99.989999999999995

# %%
Ecom_Data['Purchase Price'].min()
# Out:
# 0.0

# %%
Ecom_Data[Ecom_Data['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
Ecom_Data[Ecom_Data['Job']=='Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
Ecom_Data['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
Ecom_Data['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Designer, jewellery                  27
# Research officer, political party    27
# Name: Job, dtype: int64

# %%
Ecom_Data[Ecom_Data['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
#4926535242672853

# %%
Ecom_Data[Ecom_Data['Credit Card'] == 4926535242672853] [['Email','Company']]
# Out:
#                              Email                Company
# 1234  bondellen@williams-garza.com  Cole, King and Bowers

# %%
Ecom_Data.groupby('Company').count
# Out:
# <bound method DataFrameGroupBy.count of <pandas.core.groupby.DataFrameGroupBy object at 0x0000000010F8C358>>

# %%
Ecom_Data[(Ecom_Data['CC Provider']=='American Express') & (Ecom_Data['Purchase Price']>95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
Ecom_Data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
sum(Ecom_Data['CC Exp Date'].apply(lambda x: x[3:])=='25')
# Out:
# 1033

# %%
Ecom_Data['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
Ecom_Data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
Ecom_Data['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
test_email = Ecom_Data['Email'].iloc[0]

# %%
test_email.split('@')[1]
# Out:
# 'yahoo.com'

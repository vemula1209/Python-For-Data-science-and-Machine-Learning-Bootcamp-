# %%
my_file = open ('foodbar.txt')

# %%
my_file.read()
# Out:
# 'The line is changing second time kindly check\x00\x00\x00\x90\x06\xf5\x05\x00\x00\x00\x00X\x02\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x94\xc2\xf9\x05\x00\x00\x00\x00,\xe9@\x04\x00\x00\x00\x00\xd0K\xfb\x05\x00\x00\x00\x00\x00L\xfb\x05\x00\x00\x00\x000L\xfb\x05\x00\x00\x00\x00p\x0c\xf5\x05\x00\x00\x00\x00\x98\x02\x00\x00\x00\x00\x00\x00\x07\x00\x00\x00\x00\x00\x00\x00\x94\xc2\xf9\x05\x00\x00\x00\x00\x0c\xea@\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00p\x0c\xf5\x05\x00\x00\x00\x00`\xc2\xf9\x05\x00\x00\x00\x00\x86\xc2\xf9\x05\x00\x00\x00\x00\x86\xc2\xf9\x05\x00\x00\x00\x00\x94\xc2\xf9\x05\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xd8\x02\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x94\xc2\xf9\x05\x00\x00\x00\x00D\xe9@\x04\x00\x00\x00\x00\x90O\xfb\x05\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00p\x0c\xf5\x05\x00\x00\x00\x00`\xc2\xf9\x05\x00\x00\x00
# ...

# %%
my_file.close()

# %%
my_file = open('foodbar.txt')

# %%
my_file.close()

# %%
my_file.closed
# Out:
# True

# %%
my_file = open('foodbar','w+')

# %%
my_file.write('first time data is changed')

# %%
my_file.read()
# Out:
# ' ----------\n        content: dict\n            Content of the msg.\n        t\x05\x00\x00\x00eventt\x00\x00\x00\x00t\x06\x00\x00\x00submitN(\x02\x00\x00\x00t\x03\x00\x00\x00getR/\x00\x00\x00(\x04\x00\x00\x00R\x10\x00\x00\x00t\x01\x00\x00\x00_t\x07\x00\x00\x00contentt\x07\x00\x00\x00buffers(\x00\x00\x00\x00(\x00\x00\x00\x00sM\x00\x00\x00C:\\Users\\dilip\\Anaconda\\lib\\site-packages\\ipywidgets\\widgets\\widget_string.pyR1\x00\x00\x00R\x00\x00\x00s\x04\x00\x00\x00\x00\x08\x18\x01c\x03\x00\x00\x00\x04\x00\x00\x00\x04\x00\x00\x00C\x00\x00\x00s6\x00\x00\x00d\x01\x00d\x02\x00l\x00\x00}\x03\x00|\x03\x00j\x01\x00d\x03\x00t\x02\x00\x83\x02\x00\x01|\x00\x00j\x03\x00j\x04\x00|\x01\x00d\x04\x00|\x02\x00\x83\x01\x01\x01d\x02\x00S(\x05\x00\x00\x00sE\x01\x00\x00(Un)Register a callback to handle text submission.\n\n        Triggered when the user clicks enter.\n\n        Parameters\n        ----------\n        callback: callable\n            Will be called with exactly one argument: the Widget in
# ...

# %%
my_file.close()

# %%
my_file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-62aed17d4539> in <module>()
# ----> 1 my_file.read()
#
# ValueError: I/O operation on closed file

# %%
my_file = open('foodbar.txt')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# ''

# %%
my_file = open('foodbar.txt','w+')

# %%
my_file.write('first time file is opend and retutn some thing')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'first time file is opend and retutn some thing'

# %%
my_file.close()

# %%
my_file = open('foodbar.txt','w+')

# %%
my_file.write('writing some thing second time')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'writing some thing second time'

# %%
my_file.close()

# %%
my_file = open('foodbar.txt','w+')

# %%
my_file.seek(0)

# %%
my_file.write('writing someting third time')

# %%
my_file.read()
# Out:
# '\x05\x00\x00\x00\x00\xf0\x19\xcf\x05\x00\x00\x00\x00 \x1a\xcf\x05\x00\x00\x00\x00P\x1a\xcf\x05\x00\x00\x00\x00\x80\x1a\xcf\x05\x00\x00\x00\x00\xb0\x1a\xcf\x05\x00\x00\x00\x00\xe0\x1a\xcf\x05\x00\x00\x00\x00\x10\x1b\xcf\x05\x00\x00\x00\x00@\x1b\xcf\x05\x00\x00\x00\x00p\x1b\xcf\x05\x00\x00\x00\x00\xa0\x1b\xcf\x05\x00\x00\x00\x00\xd0\x1b\xcf\x05\x00\x00\x00\x00\x00\x1c\xcf\x05\x00\x00\x00\x000\x1c\xcf\x05\x00\x00\x00\x00`\x1c\xcf\x05\x00\x00\x00\x00\x90\x1c\xcf\x05\x00\x00\x00\x00\xc0\x1c\xcf\x05\x00\x00\x00\x00\xf0\x1c\xcf\x05\x00\x00\x00\x00 \x1d\xcf\x05\x00\x00\x00\x00P\x1d\xcf\x05\x00\x00\x00\x00\x80\x1d\xcf\x05\x00\x00\x00\x00\xb0\x1d\xcf\x05\x00\x00\x00\x00\xe0\x1d\xcf\x05\x00\x00\x00\x00\x10\x1e\xcf\x05\x00\x00\x00\x00@\x1e\xcf\x05\x00\x00\x00\x00p\x1e\xcf\x05\x00\x00\x00\x00\xa0\x1e\xcf\x05\x00\x00\x00\x00\xd0\x1e\xcf\x05\x00\x00\x00\x00\x00\x1f\xcf\x05\x00\x00\x00\x000\x1f\xcf\x05\x00\x00\x00\x00`\x1f\xcf\x05\x00\x00\x00\x00\x90\x1f\xcf\x05\x00\x00\x00\x00\xc0\x1f\xcf\x05\x00\
# ...

# %%
my_file.close()

# %%
my_file = open('foodbar.txt')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'writing someting third time'

# %%
my_file.seek(0)

# %%
my_file = open('foodbar.txt','w+')

# %%
my_file.write('writing some thing fourth time')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'writing some thing fourth time'

# %%
my_file.close()

# %%
my_file.closed()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-d0373e239cc7> in <module>()
# ----> 1 my_file.closed()
#
# TypeError: 'bool' object is not callable

# %%
my_file.closed()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-d0373e239cc7> in <module>()
# ----> 1 my_file.closed()
#
# TypeError: 'bool' object is not callable

# %%
my_file.closed
# Out:
# True

# %%
my_file = open('foodbar.txt')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'writing some thing fourth time'

# %%
my_file.seek(0)

# %%
my_file.close()

# %%
my_file.closed
# Out:
# True

# %%
my_file = open('foodbar.txt')

# %%
my_file = open('foodbar.txt','w+')

# %%
my_file.write('fifth time writing some thing')

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'fifth time writing some thing'

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
np.random.seed(101)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
     df [df > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0][['W','X','Y','Z']]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['W']>0) & (df['X']>0) & (df['Y']>0) &(df['Z']>0)]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#                X         Y         Z
# states
# AP      0.537525  0.924675  1.954070
# MH      0.433066  0.080414  0.016012
# CH      1.248551 -1.377353 -1.063289
# BG      0.714717  0.822399  1.097621
# DH      0.460574  0.687344 -0.125311

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -1.125948  0.537525  0.924675  1.954070
# 1     B -1.069378  0.433066  0.080414  0.016012
# 2     C -0.449777  1.248551 -1.377353 -1.063289
# 3     D  0.931864  0.714717  0.822399  1.097621
# 4     E  1.134648  0.460574  0.687344 -0.125311

# %%
newindex = 'AP MH CH BG DH'.split()

# %%
'AP MH CH BG DH'.split()
# Out:
# ['AP', 'MH', 'CH', 'BG', 'DH']

# %%
df['states'] = newindex

# %%
df
# Out:
#           W         X         Y         Z states
# A  2.706850  0.628133  0.907969  0.503826     AP
# B  0.651118 -0.319318 -0.848077  0.605965     MH
# C -2.018168  0.740122  0.528813 -0.589001     CH
# D  0.188695 -0.758872 -0.933237  0.955057     BG
# E  0.190794  1.978757  2.605967  0.683509     DH

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z states
# 0     A  2.706850  0.628133  0.907969  0.503826     AP
# 1     B  0.651118 -0.319318 -0.848077  0.605965     MH
# 2     C -2.018168  0.740122  0.528813 -0.589001     CH
# 3     D  0.188695 -0.758872 -0.933237  0.955057     BG
# 4     E  0.190794  1.978757  2.605967  0.683509     DH

# %%
df['W']>0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df.set_index('states',inplace = True)

# %%
df
# Out:
#           W         X         Y         Z states
# A  2.706850  0.628133  0.907969  0.503826     AP
# B  0.651118 -0.319318 -0.848077  0.605965     MH
# C -2.018168  0.740122  0.528813 -0.589001     CH
# D  0.188695 -0.758872 -0.933237  0.955057     BG
# E  0.190794  1.978757  2.605967  0.683509     DH

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z states
# 0     A  2.706850  0.628133  0.907969  0.503826     AP
# 1     B  0.651118 -0.319318 -0.848077  0.605965     MH
# 2     C -2.018168  0.740122  0.528813 -0.589001     CH
# 3     D  0.188695 -0.758872 -0.933237  0.955057     BG
# 4     E  0.190794  1.978757  2.605967  0.683509     DH

# %%
df
# Out:
#           W         X         Y         Z states
# A  2.706850  0.628133  0.907969  0.503826     AP
# B  0.651118 -0.319318 -0.848077  0.605965     MH
# C -2.018168  0.740122  0.528813 -0.589001     CH
# D  0.188695 -0.758872 -0.933237  0.955057     BG
# E  0.190794  1.978757  2.605967  0.683509     DH

# %%
df
# Out:
#                X         Y         Z
# states
# AP      0.537525  0.924675  1.954070
# MH      0.433066  0.080414  0.016012
# CH      1.248551 -1.377353 -1.063289
# BG      0.714717  0.822399  1.097621
# DH      0.460574  0.687344 -0.125311

# %%
df.reset_index()
# Out:
#   states         X         Y         Z
# 0     AP  0.537525  0.924675  1.954070
# 1     MH  0.433066  0.080414  0.016012
# 2     CH  1.248551 -1.377353 -1.063289
# 3     BG  0.714717  0.822399  1.097621
# 4     DH  0.460574  0.687344 -0.125311

# %%
D = {'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
D
# Out:
# {'A': [1, 2, nan], 'B': [5, nan, nan], 'C': [1, 2, 3]}

# %%
df = pd.DataFrame(D)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh =1)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# df

# %%
df = pd.DataFrame(randn(6,4),['A','B','C','D','E','F'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652
# F -0.993263  0.196800 -1.136645  0.000366

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# C  0.807706  0.072960  0.638787  0.329646

# %%
df[(df['W']>0)&(df['Y']>0)]
# Out:
#           W        X         Y         Z
# C  0.807706  0.07296  0.638787  0.329646

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.302665  1.693723 -1.706086 -1.159119
# 1     B -0.134841  0.390528  0.166905  0.184502
# 2     C  0.807706  0.072960  0.638787  0.329646
# 3     D -0.497104 -0.754070 -0.943406  0.484752
# 4     E -0.116773  1.901755  0.238127  1.996652
# 5     F -0.993263  0.196800 -1.136645  0.000366

# %%
newindex = 'AP TM TG MH DEL GU'.split()

# %%
newindex
# Out:
# ['AP', 'TM', 'TG', 'MH', 'DEL', 'GU']

# %%
df['States'] = newindex

# %%
df
# Out:
#           W         X         Y         Z States
# A  0.302665  1.693723 -1.706086 -1.159119     AP
# B -0.134841  0.390528  0.166905  0.184502     TM
# C  0.807706  0.072960  0.638787  0.329646     TG
# D -0.497104 -0.754070 -0.943406  0.484752     MH
# E -0.116773  1.901755  0.238127  1.996652    DEL
# F -0.993263  0.196800 -1.136645  0.000366     GU

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z States
# 0     A  0.302665  1.693723 -1.706086 -1.159119     AP
# 1     B -0.134841  0.390528  0.166905  0.184502     TM
# 2     C  0.807706  0.072960  0.638787  0.329646     TG
# 3     D -0.497104 -0.754070 -0.943406  0.484752     MH
# 4     E -0.116773  1.901755  0.238127  1.996652    DEL
# 5     F -0.993263  0.196800 -1.136645  0.000366     GU

# %%
df
# Out:
#           W         X         Y         Z States
# A  0.302665  1.693723 -1.706086 -1.159119     AP
# B -0.134841  0.390528  0.166905  0.184502     TM
# C  0.807706  0.072960  0.638787  0.329646     TG
# D -0.497104 -0.754070 -0.943406  0.484752     MH
# E -0.116773  1.901755  0.238127  1.996652    DEL
# F -0.993263  0.196800 -1.136645  0.000366     GU

# %%
df
# Out:
#           W         X         Y         Z States
# A  0.302665  1.693723 -1.706086 -1.159119     AP
# B -0.134841  0.390528  0.166905  0.184502     TM
# C  0.807706  0.072960  0.638787  0.329646     TG
# D -0.497104 -0.754070 -0.943406  0.484752     MH
# E -0.116773  1.901755  0.238127  1.996652    DEL
# F -0.993263  0.196800 -1.136645  0.000366     GU

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# AP      0.302665  1.693723 -1.706086 -1.159119
# TM     -0.134841  0.390528  0.166905  0.184502
# TG      0.807706  0.072960  0.638787  0.329646
# MH     -0.497104 -0.754070 -0.943406  0.484752
# DEL    -0.116773  1.901755  0.238127  1.996652
# GU     -0.993263  0.196800 -1.136645  0.000366

# %%
df[(df['W']>0) | (df['Y']>0)]
# Out:
#           W         X         Y         Z States
# A  0.302665  1.693723 -1.706086 -1.159119     AP
# B -0.134841  0.390528  0.166905  0.184502     TM
# C  0.807706  0.072960  0.638787  0.329646     TG
# E -0.116773  1.901755  0.238127  1.996652    DEL

# %%
my_file = open('diliptest.txt')

# %%
my_file.read()
# Out:
# 'this is the finally changed text\
# ...

# %%
my_file.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1a56cca32619> in <module>()
# ----> 1 my_file.clear()
#
# AttributeError: 'file' object has no attribute 'clear'

# %%
my_file.seek()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-890e5445147b> in <module>()
# ----> 1 my_file.seek()
#
# TypeError: seek() takes at least 1 argument (0 given)

# %%
my_file.seek(0)

# %%
my_file.read()
# Out:
# 'this is the finally changed text\
# ...

# %%
my_file = open('diliptest.txt','w+')

# %%
my_file.write('final test kindly  check')

# %%
my_file.read()
# Out:
# 'urrently chosen\n    option values, ``value``, or their labels, ``selected_labels`` must both be\n    updated with a list-like object.\n    t\x12\x00\x00\x00SelectMultipleViewR&\x00\x00\x00t\x13\x00\x00\x00SelectMultipleModel(\x08\x00\x00\x00RC\x00\x00\x00RD\x00\x00\x00RE\x00\x00\x00R\x06\x00\x00\x00RF\x00\x00\x00RG\x00\x00\x00R]\x00\x00\x00RR\x00\x00\x00(\x00\x00\x00\x00(\x00\x00\x00\x00(\x00\x00\x00\x00sP\x00\x00\x00C:\\Users\\dilip\\Anaconda\\lib\\site-packages\\ipywidgets\\widgets\\widget_selection.pyRs\x00\x00\x00\x07\x01\x00\x00s\x06\x00\x00\x00\x06\x07\x06\x01\x18\x01N()\x00\x00\x00RE\x00\x00\x00t\x0b\x00\x00\x00collectionsR\x00\x00\x00\x00t\t\x00\x00\x00itertoolsR\x01\x00\x00\x00t\x0b\x00\x00\x00ImportErrort\x03\x00\x00\x00zipt\t\x00\x00\x00domwidgetR\x02\x00\x00\x00t\x0b\x00\x00\x00valuewidgetR\x03\x00\x00\x00t\x0b\x00\x00\x00widget_coreR\x04\x00\x00\x00t\x06\x00\x00\x00widgetR\x05\x00\x00\x00t\t\x00\x00\x00traitletsR\x06\x00\x00\x00R\x07\x00\x00\x00R\x08\x00\x00\x00R\t\x00
# ...

# %%
pwd
# Out:
# u'C:\\Users\\dilip'

# %%
# %%writefile text.txt
# first line
# second line
# Out:
# Writing text.txt

# %%
my_file = open('text.txt')

# %%
my_file.read()
# Out:
# 'first line\nsecond line'

# %%
for line in open('text.txt'):
    print line
# Out:
# first line
#
# second line

# %%
my_file = open('text.txt','w+')

# %%
my_file.write('check')

# %%
my_file.read()
# Out:
# ' test kindly  checkurrently chosen\n    option values, ``value``, or their labels, ``selected_labels`` must both be\n    updated with a list-like object.\n    t\x12\x00\x00\x00SelectMultipleViewR&\x00\x00\x00t\x13\x00\x00\x00SelectMultipleModel(\x08\x00\x00\x00RC\x00\x00\x00RD\x00\x00\x00RE\x00\x00\x00R\x06\x00\x00\x00RF\x00\x00\x00RG\x00\x00\x00R]\x00\x00\x00RR\x00\x00\x00(\x00\x00\x00\x00(\x00\x00\x00\x00(\x00\x00\x00\x00sP\x00\x00\x00C:\\Users\\dilip\\Anaconda\\lib\\site-packages\\ipywidgets\\widgets\\widget_selection.pyRs\x00\x00\x00\x07\x01\x00\x00s\x06\x00\x00\x00\x06\x07\x06\x01\x18\x01N()\x00\x00\x00RE\x00\x00\x00t\x0b\x00\x00\x00collectionsR\x00\x00\x00\x00t\t\x00\x00\x00itertoolsR\x01\x00\x00\x00t\x0b\x00\x00\x00ImportErrort\x03\x00\x00\x00zipt\t\x00\x00\x00domwidgetR\x02\x00\x00\x00t\x0b\x00\x00\x00valuewidgetR\x03\x00\x00\x00t\x0b\x00\x00\x00widget_coreR\x04\x00\x00\x00t\x06\x00\x00\x00widgetR\x05\x00\x00\x00t\t\x00\x00\x00traitletsR\x06\x00\x00\x00R\x07\x00\x00\x00R\x08
# ...

# %%
for line in open('text.txt'):
    print line

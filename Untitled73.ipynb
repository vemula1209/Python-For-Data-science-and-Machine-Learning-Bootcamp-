# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color = 'Green',linewidth = 2,linestyle = '--',marker = 'o',markersize = 10,markerfacecolor = 'Yellow'
        ,markeredgewidth = 3,markeredgecolor = 'red')

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel('X axies')
axes.set_ylabel('Y axies')
axes.set_title('First Graph')

# %%
fig,axes = plt.subplots()
axes1 = fig.add_axes([0,0,1,1])
axes1.plot(x,y)
axes1.set_xlabel('X axes')
axes1.set_ylabel('Y axis')
axes1.set_title('First Graph')
axes2 = fig.add_axes([0.2,0.5,0.2,0.2])
axes2.plot(x,y)
axes2.set_xlabel('X axes')
axes2.set_ylabel('Y axis')
axes2.set_title('First Graph')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes1.plot(x,Z)
axes1.set_xlabel('x Axes')
axes1.set_ylabel('z Axes')
axes1.set_title('Firs Graph')
axes2 = fig.add_axes([0.2,0.5,0.4,0.4])
axes2.plot(x,y)
axes2.set_xlabel('x Axes')
axes2.set_ylabel('y Axes')
axes2.set_title('SECOND Graph')

# %%
fig,axes = plt.subplots(nrows= 1,ncols= 2,figsize=(10,2),dpi = 100)
axes[0].plot(x,y,lw =2,ls = '--')
axes[0].set_xlabel('X axes')
axes[0].set_ylabel('Y axes')
axes[0].set_title('First Graph')
axes[1].plot(x,z,color  =  'Red',lw =2,)
axes[1].set_xlabel('X axes')
axes[1].set_ylabel('Y axes')
axes[1].set_title('Second Graph')
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows= 1,ncols= 2)
plt.tight_layout()

# %%
import pandas as pd

# %%
pf = pd.read_csv()

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde = False,bins = 30)

# %%
sns.distplot(tips['total_bill'],kde = False,bins = 60)

# %%
sns.jointplot(x ='total_bill' ,y = 'tip' ,data = tips,kind='kde')

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips_data = sns.load_dataset('tips')

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(y='total_bill',x='day',data=tips_data,hue='sex')

# %%
sns.barplot(y='total_bill',x='day',data=tips_data,hue='sex')

# %%
sns.jointplot(x = 'total_bill',y = 'tip', data = tips_data)

# %%
sns.pairplot(data = tips_data,hue='sex')

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.barplot(x='sex',y='tip',data= tips_data)

# %%
sns.countplot(x='sex',data= tips_data)

# %%
sns.regplot(x ='total_bill',y = 'tip',data = tips_data)

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-59-e9b8e07653fc> in <module>()
# ----> 1 titanic = sns.load_dataset('titanic')
#
# C:\Users\dilip\Anaconda\lib\site-packages\seaborn\utils.pyc in load_dataset(name, cache, data_home, **kws)
#     408                                   os.path.basename(full_path))
#     409         if not os.path.exists(cache_path):
# --> 410             urlretrieve(full_path, cache_path)
#     411         full_path = cache_path
#     412
#
# C:\Users\dilip\Anaconda\lib\urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# C:\Users\dilip\Anaconda\lib\urllib.pyc in retrieve(self, url, filename, reporthook, data)
# ...

# %%
titanic = sns.load_dataset('titanic')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-60-e9b8e07653fc> in <module>()
# ----> 1 titanic = sns.load_dataset('titanic')
#
# C:\Users\dilip\Anaconda\lib\site-packages\seaborn\utils.pyc in load_dataset(name, cache, data_home, **kws)
#     408                                   os.path.basename(full_path))
#     409         if not os.path.exists(cache_path):
# --> 410             urlretrieve(full_path, cache_path)
#     411         full_path = cache_path
#     412
#
# C:\Users\dilip\Anaconda\lib\urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# C:\Users\dilip\Anaconda\lib\urllib.pyc in retrieve(self, url, filename, reporthook, data)
# ...
